# %%
import tensorflow as tf
import tensorflow.contrib.slim as slim
import numpy as np
import math
import tflearn
import random

from tensorflow.contrib.slim.python.slim.nets import resnet_v2
from tensorflow.contrib.slim.python.slim.nets import resnet_utils
from tflearn.datasets import cifar10

# %%
# initialize data
(X, Y), (X_test, Y_test) = cifar10.load_data(one_hot=True)

image_size = 32
channels = 3
classes = 10

random.seed(31415)

split_prob = 0.95

images = []
labels = []
validation_images = []
validation_labels = []

# split training/validation sets
for (image,label) in zip(X,Y):
    if random.random() < split_prob:
        images.append(image)
        labels.append(label)
    else:
        validation_images.append(image)
        validation_labels.append(label)

images = np.asarray(images)
labels = np.asarray(labels)

validation_images = np.asarray(validation_images)
validation_labels = np.asarray(validation_labels)

images = images.reshape(images.shape[0], image_size,image_size, channels)

num_datapoints = images.shape[0]

validation_images = validation_images.reshape(
    validation_images.shape[0], image_size, image_size, channels
)

test_images = X_test
test_images = test_images.reshape(test_images.shape[0], image_size,image_size,channels)
test_labels = Y_test

# %%
# define model

dropout_keep_prob = 0.5
def my_res_net(images):
    net = images
    
    net = slim.conv2d(net, 64, [5,5], scope='conv1')
    net = slim.max_pool2d(net, [2,2], scope='pool1')
    blocks = [
        resnet_utils.Block('block1', resnet_v2.bottleneck,
                         [(256, 64, 1)] * 2 + [(256, 64, 2)]),
        resnet_utils.Block('block2', resnet_v2.bottleneck,
                         [(512, 128, 1)] * 3 + [(512, 128, 2)])
    ]
    net, _ = resnet_v2.resnet_v2(net,
                                 blocks,
                                 classes,
                                 True,
                                 None,
                                 include_root_block=True,
                                 reuse=None,
                                 scope='resnet_v2')
    
    net = slim.flatten(net, scope='flatten3')
    net = slim.fully_connected(net, 1024, scope='fully_connected4')

    net = slim.fully_connected(net,
                               classes,
                               activation_fn=None,
                               scope='fully_connected_out')
    return net
        

x = tf.placeholder(tf.float32, shape=[None, image_size, image_size, channels])
y = tf.placeholder(tf.float32, shape=[None, classes])

predictions = my_res_net(x)
total_loss = tf.nn.softmax_cross_entropy_with_logits(
    logits=predictions,labels=y
)

correct = tf.equal(tf.argmax(predictions,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

learn_rate = 1e-4
train_step = tf.train.AdamOptimizer(learn_rate).minimize(total_loss)

# %%
# train model

batch_size = 20

epochs = 100
iterations = math.ceil(num_datapoints / batch_size)
print ("datapoints: {}".format(num_datapoints))
print ("epochs: {}".format(epochs))
print ("iterations: {}".format(iterations))

sess = tf.Session()
sess.run(tf.global_variables_initializer())
validate = math.floor(iterations/(100/epochs))
for e in range(epochs):
    for i in range(iterations):
        idx = batch_size*i
        batch_images = images[idx:idx+batch_size]
        batch_images = batch_images.reshape(
            batch_images.shape[0],
            image_size, image_size,
            channels).tolist()
        batch_labels = labels[idx:idx+batch_size]
        batch_labels = batch_labels.reshape(batch_labels.shape[0], classes).tolist()

        sess.run(train_step, feed_dict={x: batch_images, y:batch_labels})

        if i%validate == 0:
            train_accuracy = sess.run(
                accuracy,
                feed_dict={x: validation_images, y:validation_labels}
            )
            print("epoch: {}, iteration: {}, training accuracy: {}"
                  .format(e, i, train_accuracy))
# Out:
# datapoints: 47467
# epochs: 100
# iterations: 2374
# epoch: 0, iteration: 0, training accuracy: 0.11527832597494125
# epoch: 1, iteration: 0, training accuracy: 0.572838544845581
# epoch: 2, iteration: 0, training accuracy: 0.6213975548744202
# epoch: 3, iteration: 0, training accuracy: 0.6537702083587646
# epoch: 4, iteration: 0, training accuracy: 0.6604816317558289
# epoch: 5, iteration: 0, training accuracy: 0.6616660356521606
# epoch: 6, iteration: 0, training accuracy: 0.666008710861206
# epoch: 7, iteration: 0, training accuracy: 0.655744194984436
# epoch: 8, iteration: 0, training accuracy: 0.656928539276123
# epoch: 9, iteration: 0, training accuracy: 0.6521911025047302
# epoch: 10, iteration: 0, training accuracy: 0.6589024662971497
# epoch: 11, iteration: 0, training accuracy: 0.6616660356521606
# epoch: 12, iteration: 0, training accuracy: 0.6683773994445801
# epoch: 13, iteration: 0, training accuracy: 0.6746940612792969
# epoch: 14, iteration: 0, training accuracy: 0.6715357303619385
# epoch: 15, iteration: 0, training accuracy: 0.6640347242355347
# epoch: 16, iteration: 0, training accuracy: 0.6640347242355347
# epoch: 17, iteration: 0, training accuracy: 0.6687722206115723
# epoch: 18, iteration: 0, training accuracy: 0.6652191281318665
# epoch: 19, iteration: 0, training accuracy: 0.6750888228416443
# epoch: 20, iteration: 0, training accuracy: 0.6723253130912781
# epoch: 21, iteration: 0, training accuracy: 0.6810106635093689
# epoch: 22, iteration: 0, training accuracy: 0.6687722206115723
# epoch: 23, iteration: 0, training accuracy: 0.6632451415061951
# epoch: 24, iteration: 0, training accuracy: 0.666008710861206
# epoch: 25, iteration: 0, training accuracy: 0.6782471537590027
# epoch: 26, iteration: 0, training accuracy: 0.6746940612792969
# epoch: 27, iteration: 0, training accuracy: 0.6869325041770935
# epoch: 28, iteration: 0, training accuracy: 0.6893012523651123
# epoch: 29, iteration: 0, training accuracy: 0.6790367364883423
# epoch: 30, iteration: 0, training accuracy: 0.6833794116973877
# epoch: 31, iteration: 0, training accuracy: 0.6802210807800293
# epoch: 32, iteration: 0, training accuracy: 0.6904855966567993
# epoch: 33, iteration: 0, training accuracy: 0.6806158423423767
# epoch: 34, iteration: 0, training accuracy: 0.6802210807800293
# epoch: 35, iteration: 0, training accuracy: 0.6837741732597351
# epoch: 36, iteration: 0, training accuracy: 0.6778523325920105
# epoch: 37, iteration: 0, training accuracy: 0.6711409687995911
# epoch: 38, iteration: 0, training accuracy: 0.6770627498626709
# epoch: 39, iteration: 0, training accuracy: 0.6920647621154785
# epoch: 40, iteration: 0, training accuracy: 0.6885116696357727
# epoch: 41, iteration: 0, training accuracy: 0.6853533387184143
# epoch: 42, iteration: 0, training accuracy: 0.6849585175514221
# epoch: 43, iteration: 0, training accuracy: 0.6893012523651123
# epoch: 44, iteration: 0, training accuracy: 0.6889064311981201
# epoch: 45, iteration: 0, training accuracy: 0.6881168484687805
# epoch: 46, iteration: 0, training accuracy: 0.6928543448448181
# epoch: 47, iteration: 0, training accuracy: 0.6932491064071655
# epoch: 48, iteration: 0, training accuracy: 0.6932491064071655
# epoch: 49, iteration: 0, training accuracy: 0.6869325041770935
# epoch: 50, iteration: 0, training accuracy: 0.6893012523651123
# epoch: 51, iteration: 0, training accuracy: 0.6952230334281921
# epoch: 52, iteration: 0, training accuracy: 0.6940386891365051
# epoch: 53, iteration: 0, training accuracy: 0.6806158423423767
# epoch: 54, iteration: 0, training accuracy: 0.6928543448448181
# epoch: 55, iteration: 0, training accuracy: 0.7035136222839355
# epoch: 56, iteration: 0, training accuracy: 0.6774575710296631
# epoch: 57, iteration: 0, training accuracy: 0.6948282718658447
# epoch: 58, iteration: 0, training accuracy: 0.6975917816162109
# epoch: 59, iteration: 0, training accuracy: 0.6916699409484863
# epoch: 60, iteration: 0, training accuracy: 0.6964074373245239
# epoch: 61, iteration: 0, training accuracy: 0.6869325041770935
# epoch: 62, iteration: 0, training accuracy: 0.6932491064071655
# epoch: 63, iteration: 0, training accuracy: 0.6952230334281921
# epoch: 64, iteration: 0, training accuracy: 0.6865376830101013
# epoch: 65, iteration: 0, training accuracy: 0.6861429214477539
# epoch: 66, iteration: 0, training accuracy: 0.6924595236778259
# epoch: 67, iteration: 0, training accuracy: 0.6865376830101013
# epoch: 68, iteration: 0, training accuracy: 0.7007501125335693
# epoch: 69, iteration: 0, training accuracy: 0.7058823704719543
# epoch: 70, iteration: 0, training accuracy: 0.6825898289680481
# epoch: 71, iteration: 0, training accuracy: 0.6896960139274597
# epoch: 72, iteration: 0, training accuracy: 0.7011448740959167
# epoch: 73, iteration: 0, training accuracy: 0.6952230334281921
# epoch: 74, iteration: 0, training accuracy: 0.698776125907898
# epoch: 75, iteration: 0, training accuracy: 0.6979866027832031
# epoch: 76, iteration: 0, training accuracy: 0.6920647621154785
# epoch: 77, iteration: 0, training accuracy: 0.712988555431366
# epoch: 78, iteration: 0, training accuracy: 0.6983813643455505
# epoch: 79, iteration: 0, training accuracy: 0.6960126161575317
# epoch: 80, iteration: 0, training accuracy: 0.6956178545951843
# epoch: 81, iteration: 0, training accuracy: 0.6960126161575317
# epoch: 82, iteration: 0, training accuracy: 0.6944334506988525
# epoch: 83, iteration: 0, training accuracy: 0.6900907754898071
# epoch: 84, iteration: 0, training accuracy: 0.6960126161575317
# epoch: 85, iteration: 0, training accuracy: 0.6971970200538635
# epoch: 86, iteration: 0, training accuracy: 0.6975917816162109
# epoch: 87, iteration: 0, training accuracy: 0.6983813643455505
# epoch: 88, iteration: 0, training accuracy: 0.6999605298042297
# epoch: 89, iteration: 0, training accuracy: 0.6893012523651123
# epoch: 90, iteration: 0, training accuracy: 0.6908803582191467
# epoch: 91, iteration: 0, training accuracy: 0.6896960139274597
# epoch: 92, iteration: 0, training accuracy: 0.6983813643455505
# epoch: 93, iteration: 0, training accuracy: 0.6952230334281921
# epoch: 94, iteration: 0, training accuracy: 0.698776125907898
# epoch: 95, iteration: 0, training accuracy: 0.7043032050132751
# epoch: 96, iteration: 0, training accuracy: 0.6991709470748901
# epoch: 97, iteration: 0, training accuracy: 0.6995657086372375
# epoch: 98, iteration: 0, training accuracy: 0.7015396952629089
# epoch: 99, iteration: 0, training accuracy: 0.7058823704719543

# %%
# evalutate test data

test_accuracy = sess.run(
    accuracy,
    feed_dict={x: test_images, y:test_labels}
)

print("test accuracy: {}".format(test_accuracy))
# Out:
# test accuracy: 0.6930999755859375
